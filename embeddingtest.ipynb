# %% [markdown]
# <a href="https://colab.research.google.com/github/parinchaipunya/parinchaipunya/blob/main/embeddingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2*np.pi,2*np.pi)
y = np.sin(x)

plt.plot(x,y)
plt.show()
